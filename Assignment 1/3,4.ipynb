# %% [markdown]
# For this work, KFUPM & King Abdulaziz Center for World Culture has been selected.

# %%
# %pip install -q osmnx folium networkx shapely pyproj
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import osmnx as ox
import networkx as nx
import folium
import time
import random
import math

# %%
# Coordinates: (lat, lon)
kfupm = (26.3066, 50.1450)
ithra = (26.3278, 50.1545)

# Map center
center = ((kfupm[0] + ithra[0]) / 2,
          (kfupm[1] + ithra[1]) / 2)

print("KFUPM:", kfupm)
print("Ithra:", ithra)
print("Center:", center)
def base_map(center, kfupm, ithra):
    m = folium.Map(location=center, zoom_start=14)
    folium.Marker(kfupm, popup="KFUPM", icon=folium.Icon(color="blue")).add_to(m)
    folium.Marker(ithra, popup="Ithra", icon=folium.Icon(color="green")).add_to(m)
    return m

m0 = base_map(center, kfupm, ithra)
m0
# Out:
# KFUPM: (26.3066, 50.145)
# Ithra: (26.3278, 50.1545)
# Center: (26.3172, 50.14975)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4c218ac25b1ef9daa377a730c66ef3bc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4c218ac25b1ef9daa377a730c66ef3bc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4c218ac25b1ef9daa377a730c66ef3bc = L.map(
#                 &quot;map_4c218ac25b1ef9daa377a730c66ef3bc&quot;,
#                 {
#                     center: [26.3172, 50.14975],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ecd63499e4c46acabdb9e9038efe80c9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ecd63499e4c46acabdb9e9038efe80c9.addTo(map_4c218ac25b1ef9daa377a730c66ef3bc);
#
#
#             var marker_4959e58de0b30f4fab3c2d6f75ac1daa = L.marker(
#                 [26.3066, 50.145],
#                 {
# }
#             ).addTo(map_4c218ac25b1ef9daa377a730c66ef3bc);
#
#
#             var icon_c721cc02ce9d9b6ab8cc4dffd3831786 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_0d3307d9cf44820d6150ef5250385ca5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1dee52d0438c8d977d5c942956ec7e50 = $(`&lt;div id=&quot;html_1dee52d0438c8d977d5c942956ec7e50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KFUPM&lt;/div&gt;`)[0];
#                 popup_0d3307d9cf44820d6150ef5250385ca5.setContent(html_1dee52d0438c8d977d5c942956ec7e50);
#
#
#
#         marker_4959e58de0b30f4fab3c2d6f75ac1daa.bindPopup(popup_0d3307d9cf44820d6150ef5250385ca5)
#         ;
#
#
#
#
#                 marker_4959e58de0b30f4fab3c2d6f75ac1daa.setIcon(icon_c721cc02ce9d9b6ab8cc4dffd3831786);
#
#
#             var marker_7f82fb9c119964cdd1696da8a73cdb30 = L.marker(
#                 [26.3278, 50.1545],
#                 {
# }
#             ).addTo(map_4c218ac25b1ef9daa377a730c66ef3bc);
#
#
#             var icon_dcdbd9088996cfdc56a4fb6fac2a276b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_abeaf0367ebcbb45698e1c6a069d740a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ab8926c794274cee4f54b7de8262cd7b = $(`&lt;div id=&quot;html_ab8926c794274cee4f54b7de8262cd7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ithra&lt;/div&gt;`)[0];
#                 popup_abeaf0367ebcbb45698e1c6a069d740a.setContent(html_ab8926c794274cee4f54b7de8262cd7b);
#
#
#
#         marker_7f82fb9c119964cdd1696da8a73cdb30.bindPopup(popup_abeaf0367ebcbb45698e1c6a069d740a)
#         ;
#
#
#
#
#                 marker_7f82fb9c119964cdd1696da8a73cdb30.setIcon(icon_dcdbd9088996cfdc56a4fb6fac2a276b);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Graph

# %%
ox.settings.use_cache = True
ox.settings.log_console = True
ox.settings.timeout = 180

G = ox.graph_from_point(center, dist=3000, network_type="drive", simplify=True)

print("Nodes:", len(G.nodes))
print("Edges:", len(G.edges))
# Out:
# Nodes: 2674
# Edges: 6530

# %% [markdown]
# Nearest Nodes & Helper Functions

# %%
src = ox.distance.nearest_nodes(G, X=kfupm[1], Y=kfupm[0])
dst = ox.distance.nearest_nodes(G, X=ithra[1], Y=ithra[0])

print("Source node:", src)
print("Destination node:", dst)
def path_length_m(G, path):
    """Total path length in meters, using edge 'length'."""
    total = 0.0
    for u, v in zip(path[:-1], path[1:]):
        data = G.get_edge_data(u, v)
        best = min(attr.get("length", float("inf")) for attr in data.values())
        total += best
    return total

def add_route_to_map(m, G, path, name, color=None):
    """Add route to map."""
    coords = [(G.nodes[n]["y"], G.nodes[n]["x"]) for n in path]
    folium.PolyLine(coords, tooltip=name, weight=5, color=color).add_to(m)
    return m
# Out:
# Source node: 6582857339
# Destination node: 1489746234

# %% [markdown]
# BFS

# %%
start = time.perf_counter()
bfs_path = nx.shortest_path(G, source=src, target=dst)
bfs_time = time.perf_counter() - start
bfs_dist = path_length_m(G, bfs_path)

print(f"BFS time: {bfs_time:.6f} s")
print(f"BFS distance: {bfs_dist:.0f} m")

m_bfs = base_map(center, kfupm, ithra)
m_bfs = add_route_to_map(m_bfs, G, bfs_path, "BFS", color="blue")
m_bfs
# Out:
# BFS time: 0.000722 s
# BFS distance: 6492 m
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e75174fe11dcb9f9037e0fb8e729240a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e75174fe11dcb9f9037e0fb8e729240a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e75174fe11dcb9f9037e0fb8e729240a = L.map(
#                 &quot;map_e75174fe11dcb9f9037e0fb8e729240a&quot;,
#                 {
#                     center: [26.3172, 50.14975],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f5c6883d4fb594452576da248e8c0bac = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f5c6883d4fb594452576da248e8c0bac.addTo(map_e75174fe11dcb9f9037e0fb8e729240a);
#
#
#             var marker_3e661303155419e1a14eed8d2450d363 = L.marker(
#                 [26.3066, 50.145],
#                 {
# }
#             ).addTo(map_e75174fe11dcb9f9037e0fb8e729240a);
#
#
#             var icon_84b488324a979f4132986cedc48f8e0c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_629509d395f0bf6ce31f320d66d79459 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6bd670ff59a5c1cbd809621f7799039c = $(`&lt;div id=&quot;html_6bd670ff59a5c1cbd809621f7799039c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KFUPM&lt;/div&gt;`)[0];
#                 popup_629509d395f0bf6ce31f320d66d79459.setContent(html_6bd670ff59a5c1cbd809621f7799039c);
#
#
#
#         marker_3e661303155419e1a14eed8d2450d363.bindPopup(popup_629509d395f0bf6ce31f320d66d79459)
#         ;
#
#
#
#
#                 marker_3e661303155419e1a14eed8d2450d363.setIcon(icon_84b488324a979f4132986cedc48f8e0c);
#
#
#             var marker_c772a78554b51493a4418506b7702e61 = L.marker(
#                 [26.3278, 50.1545],
#                 {
# }
#             ).addTo(map_e75174fe11dcb9f9037e0fb8e729240a);
#
#
#             var icon_de71352b14a9a33220ad07b56cdfda42 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_7bdc3c509302a4ef60cabd73a6fb5af9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5bb26ee3e7c87c400b09895cc336591a = $(`&lt;div id=&quot;html_5bb26ee3e7c87c400b09895cc336591a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ithra&lt;/div&gt;`)[0];
#                 popup_7bdc3c509302a4ef60cabd73a6fb5af9.setContent(html_5bb26ee3e7c87c400b09895cc336591a);
#
#
#
#         marker_c772a78554b51493a4418506b7702e61.bindPopup(popup_7bdc3c509302a4ef60cabd73a6fb5af9)
#         ;
#
#
#
#
#                 marker_c772a78554b51493a4418506b7702e61.setIcon(icon_de71352b14a9a33220ad07b56cdfda42);
#
#
#             var poly_line_cb64fcd9816c3131f88ef4d13aeed6c3 = L.polyline(
#                 [[26.3072214, 50.1460528], [26.3070454, 50.1462138], [26.3078756, 50.1472027], [26.308959, 50.1486887], [26.3089989, 50.1487456], [26.3090903, 50.1487409], [26.3147778, 50.1400041], [26.3155832, 50.139715], [26.3167318, 50.1400445], [26.3187704, 50.1457195], [26.321158, 50.1496151], [26.3216629, 50.1504852], [26.3209676, 50.1502323], [26.3216677, 50.1497082], [26.324779, 50.1465339], [26.3259244, 50.1453687], [26.3261083, 50.1452534], [26.3262198, 50.1458302], [26.3260451, 50.146672], [26.3254858, 50.1494143], [26.3257317, 50.1540745], [26.3262488, 50.1544863], [26.3263259, 50.1543614], [26.3266244, 50.1538217], [26.3273273, 50.1540095], [26.3281027, 50.1539715]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_e75174fe11dcb9f9037e0fb8e729240a);

# %% [markdown]
# DFS

# %%
def dfs_path_find(G, source, target):
    stack = [(source, [source])]
    visited = set()

    while stack:
        node, path = stack.pop()
        if node == target:
            return path
        if node in visited:
            continue
        visited.add(node)

        for nbr in G.successors(node):
            if nbr not in visited:
                stack.append((nbr, path + [nbr]))

    raise nx.NetworkXNoPath("DFS did not find a path")

start = time.perf_counter()
dfs_path = dfs_path_find(G, src, dst)
dfs_time = time.perf_counter() - start
dfs_dist = path_length_m(G, dfs_path)

print(f"DFS time: {dfs_time:.6f} s")
print(f"DFS distance: {dfs_dist:.0f} m")

m_dfs = base_map(center, kfupm, ithra)
m_dfs = add_route_to_map(m_dfs, G, dfs_path, "DFS", color="red")
m_dfs
# Out:
# DFS time: 0.012986 s
# DFS distance: 73468 m
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0562ae7bf94d782125450ff2b9a10529 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0562ae7bf94d782125450ff2b9a10529&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0562ae7bf94d782125450ff2b9a10529 = L.map(
#                 &quot;map_0562ae7bf94d782125450ff2b9a10529&quot;,
#                 {
#                     center: [26.3172, 50.14975],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_77d24fc8328ab96e5c104c08cdc611c8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_77d24fc8328ab96e5c104c08cdc611c8.addTo(map_0562ae7bf94d782125450ff2b9a10529);
#
#
#             var marker_10f61321572cd84f04120b93ca15fc22 = L.marker(
#                 [26.3066, 50.145],
#                 {
# }
#             ).addTo(map_0562ae7bf94d782125450ff2b9a10529);
#
#
#             var icon_0746169df6f658d10dd2fe7bbedb3d46 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_fa3a77a91b7018543fc83f3470713223 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa79807ac17b51572fe768e7f3babc0d = $(`&lt;div id=&quot;html_aa79807ac17b51572fe768e7f3babc0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KFUPM&lt;/div&gt;`)[0];
#                 popup_fa3a77a91b7018543fc83f3470713223.setContent(html_aa79807ac17b51572fe768e7f3babc0d);
#
#
#
#         marker_10f61321572cd84f04120b93ca15fc22.bindPopup(popup_fa3a77a91b7018543fc83f3470713223)
#         ;
#
#
#
#
#                 marker_10f61321572cd84f04120b93ca15fc22.setIcon(icon_0746169df6f658d10dd2fe7bbedb3d46);
#
#
#             var marker_bdfcbf4b649e760f87d08cca9bfa5920 = L.marker(
#                 [26.3278, 50.1545],
#                 {
# }
#             ).addTo(map_0562ae7bf94d782125450ff2b9a10529);
#
#
#             var icon_523cc051065184fa2dca6202b0667f59 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_9c85c9e77266a97643d866a71fc9fbc3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ae5f67391ef2a51116a0c6a1b089a87f = $(`&lt;div id=&quot;html_ae5f67391ef2a51116a0c6a1b089a87f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ithra&lt;/div&gt;`)[0];
#                 popup_9c85c9e77266a97643d866a71fc9fbc3.setContent(html_ae5f67391ef2a51116a0c6a1b089a87f);
#
#
#
#         marker_bdfcbf4b649e760f87d08cca9bfa5920.bindPopup(popup_9c85c9e77266a97643d866a71fc9fbc3)
#         ;
#
#
#
#
#                 marker_bdfcbf4b649e760f87d08cca9bfa5920.setIcon(icon_523cc051065184fa2dca6202b0667f59);
#
#
#             var poly_line_2a4a373aa95ce965b31daf247dea645f = L.polyline(
#                 [[26.3072214, 50.1460528], [26.3070454, 50.1462138], [26.3078756, 50.1472027], [26.308959, 50.1486887], [26.3051424, 50.1491228], [26.3040187, 50.1469935], [26.3147228, 50.1400243], [26.3147778, 50.1400041], [26.3155832, 50.139715], [26.3165595, 50.1393763], [26.316729, 50.139313], [26.3138959, 50.1350331], [26.3136203, 50.1343987], [26.3153214, 50.1332151], [26.3166953, 50.1333989], [26.3188578, 50.1340623], [26.3218698, 50.135465], [26.3273897, 50.1406132], [26.32774, 50.1409268], [26.3277622, 50.1415834], [26.3256412, 50.1451546], [26.3244538, 50.1466702], [26.321545, 50.1495975], [26.3210823, 50.14997], [26.3174443, 50.1526205], [26.3138873, 50.1552965], [26.3091337, 50.1582265], [26.302723, 50.1612441], [26.3018015, 50.1618224], [26.2982928, 50.1646834], [26.2976502, 50.1653225], [26.2977487, 50.1650583], [26.2980652, 50.1655667], [26.2978891, 50.1655604], [26.2984429, 50.1649894], [26.3014209, 50.1624854], [26.3031941, 50.1613338], [26.3096677, 50.1583511], [26.3146421, 50.1550272], [26.3295583, 50.1554939], [26.3298493, 50.1554546], [26.3333767, 50.1548892], [26.3341037, 50.1555467], [26.3345004, 50.1571544], [26.3342637, 50.1588114], [26.334141, 50.1591939], [26.3340648, 50.1594206], [26.333088, 50.1609289], [26.3328015, 50.1612849]

# %% [markdown]
# Dijkstra

# %%
start = time.perf_counter()
dijkstra_path = nx.shortest_path(G, source=src, target=dst, weight="length", method="dijkstra")
dijkstra_time = time.perf_counter() - start
dijkstra_dist = path_length_m(G, dijkstra_path)

print(f"Dijkstra time: {dijkstra_time:.6f} s")
print(f"Dijkstra distance: {dijkstra_dist:.0f} m")

m_dij = base_map(center, kfupm, ithra)
m_dij = add_route_to_map(m_dij, G, dijkstra_path, "Dijkstra", color="green")
m_dij
# Out:
# Dijkstra time: 0.010414 s
# Dijkstra distance: 6243 m
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a69d91c619729bbc7aaf929f1c7f835e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a69d91c619729bbc7aaf929f1c7f835e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a69d91c619729bbc7aaf929f1c7f835e = L.map(
#                 &quot;map_a69d91c619729bbc7aaf929f1c7f835e&quot;,
#                 {
#                     center: [26.3172, 50.14975],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c2dba3f6218ebe17310ab440d2e50c0e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c2dba3f6218ebe17310ab440d2e50c0e.addTo(map_a69d91c619729bbc7aaf929f1c7f835e);
#
#
#             var marker_67de684a93743cdd6aadabc6e3c92cf4 = L.marker(
#                 [26.3066, 50.145],
#                 {
# }
#             ).addTo(map_a69d91c619729bbc7aaf929f1c7f835e);
#
#
#             var icon_4242af7928cd3ef2b05ec51f6feca5f2 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_cc3000524272330a8b42c56a4e98131a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b94c9df59f67760acfdee9a52c5fda4 = $(`&lt;div id=&quot;html_8b94c9df59f67760acfdee9a52c5fda4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KFUPM&lt;/div&gt;`)[0];
#                 popup_cc3000524272330a8b42c56a4e98131a.setContent(html_8b94c9df59f67760acfdee9a52c5fda4);
#
#
#
#         marker_67de684a93743cdd6aadabc6e3c92cf4.bindPopup(popup_cc3000524272330a8b42c56a4e98131a)
#         ;
#
#
#
#
#                 marker_67de684a93743cdd6aadabc6e3c92cf4.setIcon(icon_4242af7928cd3ef2b05ec51f6feca5f2);
#
#
#             var marker_b54a8a337a4ebb52c8d3c931678f8a85 = L.marker(
#                 [26.3278, 50.1545],
#                 {
# }
#             ).addTo(map_a69d91c619729bbc7aaf929f1c7f835e);
#
#
#             var icon_2e8a748d166c8bfa160bc6215f5c68d1 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_2b679c3c3ffbc3507353a3ea7f412166 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f93d62ec41cbce33b608b04e6ec50de6 = $(`&lt;div id=&quot;html_f93d62ec41cbce33b608b04e6ec50de6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ithra&lt;/div&gt;`)[0];
#                 popup_2b679c3c3ffbc3507353a3ea7f412166.setContent(html_f93d62ec41cbce33b608b04e6ec50de6);
#
#
#
#         marker_b54a8a337a4ebb52c8d3c931678f8a85.bindPopup(popup_2b679c3c3ffbc3507353a3ea7f412166)
#         ;
#
#
#
#
#                 marker_b54a8a337a4ebb52c8d3c931678f8a85.setIcon(icon_2e8a748d166c8bfa160bc6215f5c68d1);
#
#
#             var poly_line_097dfa8a38b2d68ed8b7ac4379d8576f = L.polyline(
#                 [[26.3072214, 50.1460528], [26.3070454, 50.1462138], [26.3078756, 50.1472027], [26.308959, 50.1486887], [26.3089989, 50.1487456], [26.3092471, 50.1511977], [26.3086058, 50.1534117], [26.3085547, 50.1535026], [26.3083018, 50.1540492], [26.3059188, 50.1586497], [26.3059158, 50.1591199], [26.306392, 50.1604182], [26.3064631, 50.1606271], [26.307075, 50.1624205], [26.3075688, 50.1633641], [26.3067865, 50.1611428], [26.3065312, 50.1604493], [26.3064913, 50.160344], [26.3070248, 50.1598747], [26.3096677, 50.1583511], [26.3146421, 50.1550272], [26.3209676, 50.1502323], [26.3216677, 50.1497082], [26.324779, 50.1465339], [26.3259244, 50.1453687], [26.3261083, 50.1452534], [26.3262198, 50.1458302], [26.3260451, 50.146672], [26.3254858, 50.1494143], [26.3256172, 50.1494523], [26.3262201, 50.1496267], [26.3260253, 50.1504932], [26.3272164, 50.1510447], [26.3273553, 50.1521804], [26.3273273, 50.1540095], [26.3281027, 50.1539715]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&qu

# %% [markdown]
# Simulated Annealing
# Max. Iterations: 250, Starting Temp.: 1, Geometric Cooling with alpha = 0.995

# %%
def random_dfs_path(G, source, target):
    stack = [(source, [source])]
    visited = set()

    while stack:
        node, path = stack.pop()

        if node == target:
            return path

        if node in visited:
            continue

        visited.add(node)

        neighbors = list(G.successors(node))
        random.shuffle(neighbors)

        for nbr in neighbors:
            if nbr not in visited:
                stack.append((nbr, path + [nbr]))

    raise nx.NetworkXNoPath("No path found")


def simulated_annealing_route(G, source, target,
                              iters=400,
                              T0=10.0,
                              alpha=0.995,
                              seed=7):

    rnd = random.Random(seed)

    current = random_dfs_path(G, source, target)
    current_cost = path_length_m(G, current)

    best = current
    best_cost = current_cost

    T = T0

    for _ in range(iters):

        if len(current) < 6:
            break

        i = rnd.randint(1, len(current) - 4)
        j = rnd.randint(i + 2, len(current) - 2)

        a = current[i]
        b = current[j]

        try:
            mid = nx.shortest_path(G, source=a, target=b, weight="length")
        except nx.NetworkXNoPath:
            T *= alpha
            continue

        candidate = current[:i] + mid + current[j+1:]
        cand_cost = path_length_m(G, candidate)

        delta = cand_cost - current_cost

        if delta < 0 or rnd.random() < math.exp(-delta / T):
            current = candidate
            current_cost = cand_cost

            if cand_cost < best_cost:
                best = candidate
                best_cost = cand_cost

        T *= alpha

    return best

start = time.perf_counter()
sa_path = simulated_annealing_route(G, src, dst,
                                    iters=400,
                                    T0=10.0,
                                    alpha=0.995,
                                    seed=7)

sa_time = time.perf_counter() - start
sa_dist = path_length_m(G, sa_path)

print(f"SA time: {sa_time:.6f} s")
print(f"SA distance: {sa_dist:.0f} m")

m_sa = base_map(center, kfupm, ithra)
m_sa = add_route_to_map(m_sa, G, sa_path, "Simulated Annealing", color="purple")
m_sa
# Out:
# SA time: 0.734791 s
# SA distance: 6243 m
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2d08e56a5c96595e8e8b800d6ccdaa65 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2d08e56a5c96595e8e8b800d6ccdaa65&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2d08e56a5c96595e8e8b800d6ccdaa65 = L.map(
#                 &quot;map_2d08e56a5c96595e8e8b800d6ccdaa65&quot;,
#                 {
#                     center: [26.3172, 50.14975],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_018f0630d7a6cbe353e8c1a5cf9fba5d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_018f0630d7a6cbe353e8c1a5cf9fba5d.addTo(map_2d08e56a5c96595e8e8b800d6ccdaa65);
#
#
#             var marker_1058b2bed5af91eadf8bb20973da028a = L.marker(
#                 [26.3066, 50.145],
#                 {
# }
#             ).addTo(map_2d08e56a5c96595e8e8b800d6ccdaa65);
#
#
#             var icon_489cc8ae113ad0fbb7f4c96c51a5aa57 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c0e3f91ed014a2e6c96c16811267f1a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a1dd8512bf82de335c61367ddfdbb3c = $(`&lt;div id=&quot;html_3a1dd8512bf82de335c61367ddfdbb3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KFUPM&lt;/div&gt;`)[0];
#                 popup_c0e3f91ed014a2e6c96c16811267f1a4.setContent(html_3a1dd8512bf82de335c61367ddfdbb3c);
#
#
#
#         marker_1058b2bed5af91eadf8bb20973da028a.bindPopup(popup_c0e3f91ed014a2e6c96c16811267f1a4)
#         ;
#
#
#
#
#                 marker_1058b2bed5af91eadf8bb20973da028a.setIcon(icon_489cc8ae113ad0fbb7f4c96c51a5aa57);
#
#
#             var marker_c20b548214ece5c4515d3c67bbe76f9b = L.marker(
#                 [26.3278, 50.1545],
#                 {
# }
#             ).addTo(map_2d08e56a5c96595e8e8b800d6ccdaa65);
#
#
#             var icon_9b3aff61ff9903a7d9f6ad8718512c84 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_fbba10ce85bfde40aaa55479b62c2fcb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_397bda998fe8e60abb63c5d81518fb43 = $(`&lt;div id=&quot;html_397bda998fe8e60abb63c5d81518fb43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ithra&lt;/div&gt;`)[0];
#                 popup_fbba10ce85bfde40aaa55479b62c2fcb.setContent(html_397bda998fe8e60abb63c5d81518fb43);
#
#
#
#         marker_c20b548214ece5c4515d3c67bbe76f9b.bindPopup(popup_fbba10ce85bfde40aaa55479b62c2fcb)
#         ;
#
#
#
#
#                 marker_c20b548214ece5c4515d3c67bbe76f9b.setIcon(icon_9b3aff61ff9903a7d9f6ad8718512c84);
#
#
#             var poly_line_55582211073bdecdae24e3b0c4007ccd = L.polyline(
#                 [[26.3072214, 50.1460528], [26.3070454, 50.1462138], [26.3078756, 50.1472027], [26.308959, 50.1486887], [26.3089989, 50.1487456], [26.3092471, 50.1511977], [26.3086058, 50.1534117], [26.3085547, 50.1535026], [26.3083018, 50.1540492], [26.3059188, 50.1586497], [26.3059158, 50.1591199], [26.306392, 50.1604182], [26.3064631, 50.1606271], [26.307075, 50.1624205], [26.3075688, 50.1633641], [26.3067865, 50.1611428], [26.3065312, 50.1604493], [26.3064913, 50.160344], [26.3070248, 50.1598747], [26.3096677, 50.1583511], [26.3146421, 50.1550272], [26.3209676, 50.1502323], [26.3216677, 50.1497082], [26.324779, 50.1465339], [26.3259244, 50.1453687], [26.3261083, 50.1452534], [26.3262198, 50.1458302], [26.3260451, 50.146672], [26.3254858, 50.1494143], [26.3256172, 50.1494523], [26.3262201, 50.1496267], [26.3260253, 50.1504932], [26.3272164, 50.1510447], [26.3273553, 50.1521804], [26.3273273, 50.1540095], [26.3281027, 50.1539715]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&

# %% [markdown]
# Final comparison (Time & Distance)

# %%
results = [
    ("BFS", bfs_time, bfs_dist, len(bfs_path)),
    ("DFS", dfs_time, dfs_dist, len(dfs_path)),
    ("Dijkstra", dijkstra_time, dijkstra_dist, len(dijkstra_path)),
    ("Simulated Annealing", sa_time, sa_dist, len(sa_path)),
]

print(f"{'Algorithm':<22} {'Time(s)':>10} {'Distance(m)':>14} {'Nodes in Path':>14}")
print("-" * 64)
for name, t, d, n_nodes in results:
    print(f"{name:<22} {t:>10.6f} {d:>14.0f} {n_nodes:>14}")
# Out:
# Algorithm                 Time(s)    Distance(m)  Nodes in Path
# ----------------------------------------------------------------
# BFS                      0.000722           6492             26
# DFS                      0.012986          73468            475
# Dijkstra                 0.010414           6243             36
# Simulated Annealing      0.734791           6243             36

# %% [markdown]
# #Conclusion
# 1. BFS was the fastest algorithm (0.0007 s), but it does not consider edge weights. It produced a slightly longer route (6492 m) compared to the optimal solution.
# 2. DFS performed poorly for routing purposes.
# 3. Dijkstra produced the shortest route (6243 m) in a reasonable time.
# 4. Simulated Annealing converged to the same optimal distance as Dijkstra, but it required significantly more computation time (0.73 s), making it less efficient for small graph problems.
